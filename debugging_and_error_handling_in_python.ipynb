# %%
list_1 = ['A1', 1, 'is', 2, 'the', True, {"Whatever": "Bridge between academia and industry."}]

count_types = {}
for idx, element in enumerate(list_1):
  element_type = type(element)
  import pdb; pdb.set_trace()
  if element_type in count_types.keys():
    count_types[element_type] += 1
  #else:
  count_types[element_type] = 0
count_types
# Out:
# > /tmp/ipython-input-495/19521666.py(7)<cell line: 0>()
#       5   element_type = type(element)
#       6   import pdb; pdb.set_trace()
# ----> 7   if element_type in count_types.keys():
#       8     count_types[element_type] += 1
#       9   #else:
#
# ipdb> element
# 'A1'
# ipdb> list_1[idx]
# 'A1'
# ipdb> idx
# 0
# ipdb> element_type
# <class 'str'>
# ipdb> count_types.keys
# <built-in method keys of dict object at 0x7c9799c2e340>
# ipdb> exit

# %%
sum = 0
for element in list_1:
  try:
   sum += element
  except TypeError:
   continue
sum
# Out:
# 4
